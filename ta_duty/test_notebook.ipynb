# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
x = [1,2,2.5,3,4,4.5,5,6,7,8,8.5,9]
y = x

# %%
from matplotlib import pyplot as plt
#plt.style.use('fivethirtyeight')
#plt.style.use('seaborn-colorblind')
#plt.style.use('ggplot')

# %%
plt.style.use('fivethirtyeight')
plt.plot(y,x, 'o-b', label='y=x')
plt.title("CI PI")
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.show()

# %% [markdown]
# <H3>Figure is the container holding our plot.<hr>
# Axes are the actual plots  </H3>

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True)
